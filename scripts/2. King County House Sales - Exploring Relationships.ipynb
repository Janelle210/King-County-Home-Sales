# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # 02. Import Data

# %%
# Path to main folder
path = r'C:\Users\jmacs\Documents\Career Foundry Tasks\KingCountySales'

# %%
# Import kc_house_data
kc_house_data = pd.read_csv(os.path.join(path, 'kc_house_data_clean.csv'), index_col = False)

# %%
kc_house_data.head()
# Out:
#    Unnamed: 0          id        date   price  bedrooms  bathrooms  \
# 0           0  7129300520  2014-10-13  221900         3       1.00
# 1           1  6414100192  2014-10-13  538000         3       2.25
# 2           2  5631500400  2014-10-13  180000         2       1.00
# 3           3  2487200875  2014-10-13  604000         4       3.00
# 4           4  1954400510  2014-10-13  510000         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955           NaN    98178  47.5112 -122.257
# ...

# %%
#checking matplotlib version
matplotlib.__version__
# Out:
# '3.7.2'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %% [markdown]
# # 03. Exploring Relationships

# %% [markdown]
# ### Correlations

# %%
kc_house_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Create a subset excluding the unwanted columns columns

kc_sub = kc_house_data[['price', 'bedrooms', 'bathrooms', 'sqft_living15','sqft_lot15','floors', 'condition', 'grade']]

# %%
#checking subset
kc_sub.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living15  sqft_lot15  floors  condition  \
# 0  221900         3       1.00           1340        5650     1.0          3
# 1  538000         3       2.25           1690        7639     2.0          3
# 2  180000         2       1.00           2720        8062     1.0          3
# 3  604000         4       3.00           1360        5000     1.0          5
# 4  510000         3       2.00           1800        7503     1.0          3
#
#    grade
# 0      7
# 1      7
# 2      6
# 3      7
# 4      8

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(kc_sub.corr(), annot = True, ax = ax)

# %% [markdown]
# This heat map shows some interesting relationships between variables.
# 0: no relationship
# 0.1–0.3: weak relationship
# 0.3–0.5: moderate relationship
# 0.5–1.0: strong relationship
#
# There is a stronger relationship between price and bathrooms, sqft living space, grade.
# There is a moderate relationship between price and bedrooms.
# There is a weak relationsihp between price and sqft of the lot, number of floors, condition(surprising), year built.
#
# The bedrooms had a strong relationship to bathrooms
# moderate relationship to price, sqft living space, and grade.
#
# Bathrooms had a strong relationship to number of floors.
#
# The square foot living space had the highest correlation to grade, meaning more sqft the higher the grade.
# It also had a strong relationship between price, bedrooms, bathrooms.

# %% [markdown]
# ### Scatterplots

# %%
# Create a scatterplot for the "price" and "grade" columns in seaborn

sns.lmplot(x = 'price', y = 'grade', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "price" and "sqft_living15" columns in seaborn

sns.lmplot(x = 'price', y = 'sqft_living15', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "price" and "sqft_living15" columns in seaborn

sns.lmplot(x = 'price', y = 'bathrooms', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "price" and "bedrooms" columns in seaborn

sns.lmplot(x = 'price', y = 'bedrooms', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "grade" and "sqft_living15" columns in seaborn

sns.lmplot(x = 'grade', y = 'sqft_living15', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "grade" and "bathrooms" columns in seaborn

sns.lmplot(x = 'grade', y = 'bathrooms', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "grade" and "bedrooms" columns in seaborn

sns.lmplot(x = 'grade', y = 'bedrooms', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "bathrooms" and "floors" columns in seaborn

sns.lmplot(x = 'bathrooms', y = 'floors', data = kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# After looking at all the scatterplots, the highest areas of correlation to increase of price is grade and square foot living space. Bathrooms are highly correlated to square feet so the more square feet there are more bathrooms and therefore higher price.
#
# The only other variables that had a high correlation are the grade and the square feet living space.

# %% [markdown]
# ### Pair Plots

# %%
# Create a pair plot 

g = sns.pairplot(kc_sub)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# There are some interesting things to take away from the pair plots.
#
# There are a lot of homes with smaller sized lots for high prices.
# Most of the homes have around 3 bedrooms.
# Most homes were mid condition at about a 3 and higher (out of 5) and grade was mid about 7 to 7.5 (out of 13).

# %% [markdown]
# ### Categorical Plot

# %%
# Use a histogram to visualize the distribution of the variables. 

sns.histplot(kc_sub['price'], bins = 40, kde = True)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
# creating price category
kc_house_data.loc[kc_house_data['price'] < 360000, 'Price category'] = 'Low price'

# %%
kc_house_data.loc[(kc_house_data['price'] >= 360000) & (kc_house_data['price'] < 720000), 'Price category'] = 'Middle price'

# %%
kc_house_data.loc[kc_house_data['price'] >= 720000, 'Price category'] = 'High price'

# %%
kc_house_data['Price category'].value_counts(dropna = False)
# Out:
# Price category
# Middle price    10391
# Low price        7118
# High price       4088
# Name: count, dtype: int64

# %%
# exporting kc_house_data_clean dataframe
kc_house_data.to_csv(os.path.join(path, 'kc_house_data_clean.csv'))

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="grade", y="price", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Here we can see the breakdown of higher the grade of home the higher the price. There are a few in low price and high grade.

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="price", y="sqft_living15", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="sqft_living15", y="grade", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="sqft_lot15", y="price", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="price", y="bedrooms", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="sqft_living15", y="sqft_lot", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="condition", y="price", hue="Price category", data=kc_house_data)
# Out:
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jmacs\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Do homes with certain price points sell better/more?
#
# homes between $360,000 and $720,000 sold the most.
# high grade and large square footage contributed to high price the most.
# Most homes in mid condition about 3 (out of 5) were sold.
# Most homes in mid grade about 7/7.5 out of 13 were sold.
# Lot size did not matter for price.
#
# Does having certain bedroom counts sell better/more?
#
# Amount of bedrooms did not matter for price point.
#
# Hypothesis:
#
# If a home has a higher grade and higher square footage of living space, then the higher the home price will be.
